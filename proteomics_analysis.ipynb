# %% [markdown]
# Import packages

# %%
import pandas as pd
# Out:
# c:\Users\hetpe\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# ## Extract upregulated and downregulated genes.

# %%
pt = pd.read_csv('significant_genes_with_descriptions.csv')

# %% [markdown]
# Upregulated:

# %%
pt_up = pt[pt["direction"] == 'Upregulated']
up_list = pt_up['uniprot_id'].tolist()

# %% [markdown]
# Downregulated

# %%
pt_down = pt[pt["direction"] == 'Downregulated']
down_list = pt_down['uniprot_id'].tolist()

# %% [markdown]
# Ideas:
# - find whether or not the log ratio is different between the upregulated and downregulated group
# - find the distribution of the NAs acrross the transcriptomics (and plot)
