# %%
import pandas as pd
# Out:
# c:\Users\hetpe\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
pt = pd.read_csv('significant_genes_with_descriptions.csv')

# %% [markdown]
# Upregulated:

# %%
pt_up = pt[pt["direction"] == 'Upregulated']
print(pt_up['uniprot_id'].tolist())
# Out:
# ['Q55197', 'Q55196', 'Q55199', 'Q55198', 'Q55200', 'P73785', 'P73590', 'P73788', 'P72938', 'P72939', 'P73787', 'P73786', 'P74647', 'Q55854', 'Q55195', 'P74649', 'Q55898', 'P74648', 'P73103', 'P73176', 'P74651', 'P74652', 'Q55194', 'P74754', 'P72971', 'P73173', 'P49433', 'Q55853', 'P73175', 'P74755', 'P73563', 'P73172', 'P73174', 'Q55814', 'P74615', 'Q55770', 'P74721', 'P73159', 'P74286', 'P73160', 'P74405', 'P73739', 'P73516', 'Q6YRW2', 'P72785', 'Q06474', 'P74168', 'P74084', 'P73104', 'P73799', 'P73789', 'P74720', 'Q55727', 'P73802', 'P73702', 'P74650', 'P74586', 'P74258', 'Q6YRW5', 'Q55583', 'Q6YRW1', 'Q6YRT5', 'P77971', 'P73662', 'Q55193', 'P73843', 'P74025', 'Q55728', 'Q6YRT5', 'Q55410', 'Q6ZE74', 'P73604', 'P73603', 'P73826', 'P74257', 'P74024', 'P73825', 'P74494', 'P73547', 'P74541', 'Q55943', 'P74746', 'P73605', 'P73800', 'P73703', 'Q55847', 'Q6YRV1', 'Q55661', 'P73801', 'P73842', 'Q55846', 'Q55582', 'P74519', 'P74022', 'P74635', 'P73593', 'Q55192', 'Q55942', 'P72634', 'Q6YRW4
# ...

# %% [markdown]
# Downregulated

# %%
pt_up = pt[pt["direction"] == 'Downregulated']
pt_up['uniprot_id'].to_csv('Upregulated.txt', header = False, index = None, sep = " ", mode = 'a')
